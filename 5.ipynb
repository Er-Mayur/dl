# %%
# ---------------------------------------------------------
# Continuous Bag of Words (CBOW) Model Implementation
# ---------------------------------------------------------

# -----------------------------
# a. Import required libraries
# -----------------------------
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, Lambda, Dense
from tensorflow.keras.models import Model
# Out:
# /Users/mayur/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# -----------------------------
# b. Data Preparation
# -----------------------------
corpus = [
    "the quick brown fox jumped over the lazy dog",
    "I love natural language processing",
    "word embeddings capture semantic meaning"
]

# %%
# Tokenize words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

word2id = tokenizer.word_index
id2word = {v: k for k, v in word2id.items()}
vocab_size = len(word2id) + 1

print("Vocabulary size:", vocab_size)
print("Word to index mapping:", word2id)

# Convert text to sequences of word indices
sequences = tokenizer.texts_to_sequences(corpus)
# Out:
# Vocabulary size: 19
# Word to index mapping: {'the': 1, 'quick': 2, 'brown': 3, 'fox': 4, 'jumped': 5, 'over': 6, 'lazy': 7, 'dog': 8, 'i': 9, 'love': 10, 'natural': 11, 'language': 12, 'processing': 13, 'word': 14, 'embeddings': 15, 'capture': 16, 'semantic': 17, 'meaning': 18}

# %%
# -----------------------------
# c. Generate CBOW (context → target) training pairs
# -----------------------------
window_size = 2
data = []

for seq in sequences:
    for i in range(window_size, len(seq) - window_size):
        context = []
        
        # left context words
        for j in range(window_size):
            context.append(seq[i - j - 1])
        
        # right context words
        for j in range(window_size):
            context.append(seq[i + j + 1])
        
        target = seq[i]
        data.append((context, target))

# Show sample
c, t = data[0]
print("\nSample CBOW pair:", [id2word[w] for w in c], "->", id2word[t])

# Prepare input & output
contexts = np.array([x for x, _ in data])
targets = np.array([y for _, y in data])
targets = to_categorical(targets, vocab_size)   # one-hot targets
# Out:
# Sample CBOW pair: ['quick', 'the', 'fox', 'jumped'] -> brown

# %%
# -----------------------------
# d. Build CBOW Model
# -----------------------------
embedding_dim = 10

# Input is context words
input_layer = Input(shape=(window_size * 2,))
embedding = Embedding(vocab_size, embedding_dim)(input_layer)

# Average embeddings
x = Lambda(lambda z: tf.reduce_mean(z, axis=1))(embedding)

# Output predicts target word
output_layer = Dense(vocab_size, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output_layer)

# %%
# -----------------------------
# e. Compile the model
# -----------------------------
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 4, 10)          │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 19)             │           209 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 399 (1.56 KB)
#  Trainable params: 399 (1.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# -----------------------------
# f. Train the model
# -----------------------------
history = model.fit(contexts, targets, epochs=50, verbose=1)
print("\nCBOW model training completed successfully!")
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.1429 - loss: 2.9396
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1429 - loss: 2.9366
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 2.9335
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 2.9305
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5714 - loss: 2.9275
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 2.9245
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 2.9214
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 2.9184
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.9153
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7143 - loss: 2.9123
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.9092
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7143 - loss: 2.9061
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.9030
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7143 - loss: 2.8999
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.8968
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7143 - loss: 2.8937
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.8905
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7143 - loss: 2.8873
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8842
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8810
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8777
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8745
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8713
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8680
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8647
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8614
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8580
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8547
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8513
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8479
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8445
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8571 - loss: 2.8410
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8376
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8340
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.8305
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8270
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8234
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8571 - loss: 2.8198
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8571 - loss: 2.8161
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8125
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8088
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8050
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.8013
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.7975
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8571 - loss: 2.7937
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.7898
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 2.7859
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.7820
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8571 - loss: 2.7781
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8571 - loss: 2.7741
#
# CBOW model training completed successfully!

# %%
# -----------------------------
# g. Test prediction with known words
# -----------------------------
test_sentences = [
    "i love language processing",
    "the quick fox jumped",
    "word embeddings semantic meaning"
]

# Convert test sentences to sequences
test_sequences = tokenizer.texts_to_sequences(test_sentences)
print("\nTest sequences:", test_sequences)

# Predict center word
for seq in test_sequences:
    if len(seq) >= 4:     # need 4 context words
        ctx = np.array(seq[:4])
        ctx_words = [id2word[i] for i in ctx]

        prediction = model.predict(ctx.reshape(1, -1))
        predicted_word = id2word[np.argmax(prediction)]

        print("\nContext words:", ctx_words)
        print("Predicted center word:", predicted_word)
# Out:
# Test sequences: [[9, 10, 12, 13], [1, 2, 4, 5], [14, 15, 17, 18]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Context words: ['i', 'love', 'language', 'processing']
# Predicted center word: natural
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Context words: ['the', 'quick', 'fox', 'jumped']
# Predicted center word: over
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Context words: ['word', 'embeddings', 'semantic', 'meaning']
# Predicted center word: capture
